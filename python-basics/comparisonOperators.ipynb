# %%
## comparison operators
a = 5
b = 10

## less than
c = a < b
print(c)

## greater than
d = a > b
print(d)

## equal to 
e = a == b
print(e)

## not equal to
f = a != b
print(f)

## less than or equal to
g = a <= b
print(g)

## greater than or equal to
h = a >= b
print(h)
# Out:
# True
# False
# False
# True
# True
# False
