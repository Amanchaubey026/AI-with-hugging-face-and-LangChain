# %% [markdown]
# ## DataTypes

# %%
print("hey")
# Out:
# hey

# %%
## Integer Example
age = 27
type(age)
# Out:
# <class 'int'>

# %%
height = 6.1
type(height)
# Out:
# float

# %%
## Arithmetic Operations
## add
a = 16
b = 4
c = a + b
print(c)
# Out:
# 20

# %%
## subtract
a = 16
b = 4
c = a - b
print(c)
# Out:
# 12

# %%
## multiply
a = 16
b = 4
c = a * b
print(c)
# Out:
# 64

# %%
## divide
a = 16
b = 4
c = a / b
print(c)
# Out:
# 4.0

# %%
## floor division
a = 16
b = 4
c = a // b
print(c)

## difference between floor division and regular division is that floor division rounds down to the nearest whole number, while regular division may produce a floating-point result.
# Out:
# 4

# %%
## modulus
a = 16
b = 5
c = a % b
print(c)
# Out:
# 1
